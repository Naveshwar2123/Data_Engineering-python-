# %% [markdown]
# ## Topic ->  3- Conditional logic (if / elif / else)

# %% [markdown]
# ### Coding questions

# %% [markdown]
# ### Easy level

# %% [markdown]
# ### 1--> Check whether a number is positive, negative, or zero.

# %%
number = int(input("Enter the number "))

if number == 0:
   print("number is zero ")
elif number < 0 :
   print("Number is negative")
else :
   print("Number is positive ")
# Out:
# Number is negative

# %% [markdown]
# ### 2--> Check whether the person can vote or not

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %% [markdown]
# ### 3--> Find the larger of two numbers.

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

if number1 > number2:
    print(f"{number1} is greater than {number2}.")  
else :
    print(f"{number2} is greater than {number1}.")
# Out:
# 80 is greater than 50.

# %% [markdown]
# ### 4--> Find the largest of three numbers

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
    print("Largest number is:", num1)

elif num2 >= num1 and num2 >= num3:
    print("Largest number is:", num2)

else:
    print("Largest number is:", num3)
# Out:
# Largest number is: 96.0

# %% [markdown]
# ### Medium

# %% [markdown]
# ### 1--> Determine if a character is a vowel or consonant.

# %%
character = input("Enter a character: ")
vowel = ['a', 'e', 'i', 'o', 'u']
if character.lower() in vowel:
    print(f"{character} is a vowel.")
else:
   print(f"{character} is a consonant.")
# Out:
# D is a consonant.

# %% [markdown]
# ### Hard

# %% [markdown]
# ### 1--> Build an ATM withdrawal simulation (balance check + withdrawal).

# %%
while True :
    name = input("Enter your name : ")

    Amount = 45000

    print("For balance check enter the Balance")
    print("For withdrawl enter the withdral_amount")

    operation = input("What you want to perform ?")

    if operation == "Balance":
        print(f"{name} your balance is {Amount} ")
    elif operation == "withdral_amount" :
        W_amt = int(input("Enter the Amount you want to withdrawl :"))
        Amount = Amount - W_amt 
        print(f"{name} Thank you for withdrawl ")
        print(f"your updated amount is {Amount}")

    check = input(f"If you want to perform the task again press 1 or if not then press 0 :")

    if check != 1:
        break
# Out:
# For balance check enter the Balance
# For withdrawl enter the withdral_amount
# navi Thank you for withdrawl
# your updated amount is 44200
